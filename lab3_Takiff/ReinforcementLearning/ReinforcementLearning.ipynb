# %% [markdown]
# # **Cross-Entropy fo Reinforcement Learning**

# %% [markdown]
# Given a set of inputs, the algorithm sees the outputs produced, chooses the inputs that have led to the best outputs and tunes them till it is satisfied with the outputs. [Full article](https://towardsdatascience.com/cross-entropy-method-for-reinforcement-learning-2b6de2a4f3a0).

# %% [markdown]
# In this notebook, we will train the Cross-Entropy Method with OpenAI Gym's MountainCarContinuous environment.
# ([code on github](https://github.com/udacity/deep-reinforcement-learning/tree/master/cross-entropy)).

# %% [markdown]
# **Note on environment choices**
# The current code only works on continuous environments and will throw errors if you try a discrete environment. [Gym](https://gym.openai.com/envs/) has a lot of continuous environments like gym's *Pendulum-v1*.

# %% [markdown]
# **Install needed packages**
#
# Note: if your example problem requires packages that are not installed, please contact youru instructor to install them for you.

# %%
# Avoid multiple installation of packages on Ed
import os
if not os.getenv("ED_COURSE_ID"):
    # !pip install torch  collections gym

# %% [markdown]
# **1. Import the Necessary Packages**

# %%
import gym
import math
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %% [markdown]
# **2. Instantiate the Environment and Agent**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

env = gym.make('MountainCarContinuous-v0')
env.seed(101)
np.random.seed(101)

print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('  - low:', env.action_space.low)
print('  - high:', env.action_space.high)

class Agent(nn.Module):
    def __init__(self, env, h_size=16):
        super(Agent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.shape[0]
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)
        
    def set_weights(self, weights):
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))
    
    def get_weights_dim(self):
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.tanh(self.fc2(x))
        return x.cpu().data
        
    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            action = self.forward(state)
            state, reward, done, _ = self.env.step(action)
            episode_return += reward * math.pow(gamma, t)
            if done:
                break
        return episode_return
    
agent = Agent(env).to(device)
# Out:
# observation space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# action space: Box(-1.0, 1.0, (1,), float32)
#   - low: [-1.]
#   - high: [1.]

# %% [markdown]
# **3. Train the Agent with the Cross-Entropy Method**
#
# Run the code cell below to train the agent from scratch. Alternatively, you can skip to the next code cell to load the pre-trained weights from file.

# %%
def cem(n_iterations=500, max_t=1000, gamma=1.0, print_every=10, pop_size=50, elite_frac=0.2, sigma=0.5):
    """PyTorch implementation of the cross-entropy method.
        
    Params
    ======
        n_iterations (int): maximum number of training iterations
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        pop_size (int): size of population at each iteration
        elite_frac (float): percentage of top performers to use in update
        sigma (float): standard deviation of additive noise
    """
    n_elite=int(pop_size*elite_frac)

    scores_deque = deque(maxlen=100)
    scores = []
    best_weight = sigma*np.random.randn(agent.get_weights_dim())

    for i_iteration in range(1, n_iterations+1):
        weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
        rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])

        elite_idxs = rewards.argsort()[-n_elite:]
        elite_weights = [weights_pop[i] for i in elite_idxs]
        best_weight = np.array(elite_weights).mean(axis=0)

        reward = agent.evaluate(best_weight, gamma=1.0)
        scores_deque.append(reward)
        scores.append(reward)
        
        torch.save(agent.state_dict(), 'ReinforcementLearning/checkpoint.pth')
        
        if i_iteration % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))

        if np.mean(scores_deque)>=90.0:
            print('\nEnvironment solved in {:d} iterations!\tAverage Score: {:.2f}'.format(i_iteration-100, np.mean(scores_deque)))
            break
    return scores

scores = cem()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %% [markdown]
# **4. Watch a Smart Agent!**
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!
#
# **Note on visualization**: If the display window comes up but the environment is not displayed, please click on the "..." on the top right of the window to select "Full view", then click on the "Remote App" button (with a blue dot) to view the rendering. The environment only shows through the duration of the while loop. If the window closes, you can rerun this section (Ctrl+Enter), and click on the remote app button, to view the display again.

# %%
# !xdpyinfo
# load the weights from file
agent.load_state_dict(torch.load('ReinforcementLearning/checkpoint.pth'))

state = env.reset()
while True:
    state = torch.from_numpy(state).float().to(device)
    with torch.no_grad():
        action = agent(state)
    env.render()
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()
# Out:
# name of display:    :1.0
# version number:    11.0
# vendor string:    The X.Org Foundation
# vendor release number:    12009000
# X.Org version: 1.20.9
# maximum request size:  16777212 bytes
# motion buffer size:  256
# bitmap unit, bit order, padding:    32, LSBFirst, 32
# image byte order:    LSBFirst
# number of supported pixmap formats:    6
# supported pixmap formats:
#     depth 1, bits_per_pixel 1, scanline_pad 32
#     depth 4, bits_per_pixel 8, scanline_pad 32
#     depth 8, bits_per_pixel 8, scanline_pad 32
#     depth 16, bits_per_pixel 16, scanline_pad 32
#     depth 24, bits_per_pixel 32, scanline_pad 32
#     depth 32, bits_per_pixel 32, scanline_pad 32
# keycode range:    minimum 8, maximum 255
# focus:  window 0x20000a, revert to PointerRoot
# number of extensions:    23
#     BIG-REQUESTS
#     Composite
#     DAMAGE
#     DOUBLE-BUFFER
#     GLX
#     Generic Event Extension
#     MIT-SCREEN-SAVER
#     MIT-SHM
#     Present
#     RANDR
#     RECORD
#     RENDER
#     SHAPE
#     SYNC
#     VNC-EXTENSION
#     X-Resource
#     XC-MISC
#     XFIXES
#     XINERAMA
#     XInputExtension
#     XKEYBOARD
#     XTEST
#     XVideo
# default screen number:    0
# number of screens:    1
#
# screen #0:
#   dimensions:    1158x694 pixels (306x183 millimeters)
#   resolution:    96x96 dots per inch
#   depths (7):    1, 4, 8, 16, 24, 32, 24
#   root window id:    0x51a
#   depth of root window:    24 planes
#   number of colormaps:    minimum 1, maximum 1
#   default colormap:    0x20
#   default number of colormap cells:    256
#   preallocated pixels:    black 0, white 16777215
#   options:    backing-store WHEN MAPPED, save-unders NO
#   largest cursor:    1158x694
#   current input event mask:    0x72003c
#     ButtonPressMask          ButtonReleaseMask        EnterWindowMask
#     LeaveWindowMask          StructureNotifyMask      SubstructureRedirectMask
#     FocusChangeMask          PropertyChangeMask
#   number of visuals:    390
#   default visual id:  0x21
#   visual:
#     visual id:    0x396
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x397
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x398
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x399
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3aa
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ab
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ac
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ad
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ae
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3af
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ba
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3be
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bf
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ca
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ce
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cf
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3da
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3db
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3dc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3dd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3de
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3df
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ea
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3eb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ec
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ed
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ee
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ef
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fa
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fe
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ff
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x400
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x401
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x402
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x403
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x404
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x405
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x406
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x407
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x408
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x409
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x410
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x411
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x412
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x413
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x414
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x415
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x416
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x417
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x418
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x419
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x420
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x421
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x422
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x423
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x424
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x425
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x426
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x427
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x428
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x429
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x430
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x431
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x432
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x433
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x434
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x435
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x436
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x437
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x438
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x439
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x440
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x441
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x442
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x443
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x444
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x445
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x446
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x447
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x448
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x449
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44a
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44b
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44c
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44d
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44e
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44f
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x450
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x451
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x452
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x453
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
# ...
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4de
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4df
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e0
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e1
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e2
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e3
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e4
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e5
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e6
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e7
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e8
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e9
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ea
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4eb
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ec
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ed
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ee
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ef
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f0
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f1
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f2
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f3
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f4
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f5
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f6
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f7
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f8
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f9
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fa
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fb
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4d
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fc
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fd
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fe
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ff
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x500
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x501
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x502
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x503
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x504
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x505
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x506
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x507
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x508
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x509
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50a
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50b
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50c
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50d
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50e
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50f
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x510
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x511
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x512
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x513
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x514
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x515
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x516
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x517
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x518
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x21
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x22
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM sysdefault

# %% [markdown]
# **Earn Your Wings: Do it youorself**
#
# Test this algorithm on your own environment.

# %% [markdown]
# **Note on environment choices**
# The current code only works on continuous environments and will throw errors if you try a discrete environment. [Gym](https://gym.openai.com/envs/) has a lot of continuous environments like gym's *Pendulum-v1*.

# %% [markdown]
# **Install needed packages**
#
# Note: if your example problem requires packages that are not installed, please contact youru instructor to install them for you.

# %%
# Avoid multiple installation of packages on Ed
import os
if not os.getenv("ED_COURSE_ID"):
    # !pip install torch  collections gym

# %%
import gym
import math
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

env = gym.make('Pendulum-v1')
env.seed(101)
np.random.seed(101)

print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('  - low:', env.action_space.low)
print('  - high:', env.action_space.high)

class Agent(nn.Module):
    def __init__(self, env, h_size=16):
        super(Agent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.shape[0]
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)
        
    def set_weights(self, weights):
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))
    
    def get_weights_dim(self):
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.tanh(self.fc2(x))
        return x.cpu().data
        
    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            action = self.forward(state)
            state, reward, done, _ = self.env.step(action)
            episode_return += reward * math.pow(gamma, t)
            if done:
                break
        return episode_return
    
agent = Agent(env).to(device)
# Out:
# observation space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# action space: Box(-2.0, 2.0, (1,), float32)
#   - low: [-2.]
#   - high: [2.]

# %%
def cem(n_iterations=500, max_t=1000, gamma=1.0, print_every=10, pop_size=50, elite_frac=0.2, sigma=0.5):
    """PyTorch implementation of the cross-entropy method.
        
    Params
    ======
        n_iterations (int): maximum number of training iterations
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        pop_size (int): size of population at each iteration
        elite_frac (float): percentage of top performers to use in update
        sigma (float): standard deviation of additive noise
    """
    n_elite=int(pop_size*elite_frac)

    scores_deque = deque(maxlen=100)
    scores = []
    best_weight = sigma*np.random.randn(agent.get_weights_dim())

    for i_iteration in range(1, n_iterations+1):
        weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
        rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])

        elite_idxs = rewards.argsort()[-n_elite:]
        elite_weights = [weights_pop[i] for i in elite_idxs]
        best_weight = np.array(elite_weights).mean(axis=0)

        reward = agent.evaluate(best_weight, gamma=1.0)
        scores_deque.append(reward)
        scores.append(reward)
        
        torch.save(agent.state_dict(), 'ReinforcementLearning/checkpoint.pth')
        
        if i_iteration % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))

        if np.mean(scores_deque)>=90.0:
            print('\nEnvironment solved in {:d} iterations!\tAverage Score: {:.2f}'.format(i_iteration-100, np.mean(scores_deque)))
            break
    return scores

scores = cem()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# /usr/lib/python3.10/site-packages/torch/nn/functional.py:1933: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode 10	Average Score: -1295.73
# Episode 20	Average Score: -1334.74
# Episode 30	Average Score: -1344.60
# Episode 40	Average Score: -1328.08
# Episode 50	Average Score: -1323.43
# Episode 60	Average Score: -1342.05
# Episode 70	Average Score: -1331.45
# Episode 80	Average Score: -1328.27
# Episode 90	Average Score: -1322.22
# Episode 100	Average Score: -1327.92
# Episode 110	Average Score: -1329.62
# Episode 120	Average Score: -1309.00
# Episode 130	Average Score: -1303.12
# Episode 140	Average Score: -1307.64
# Episode 150	Average Score: -1321.26
# Episode 160	Average Score: -1305.20
# Episode 170	Average Score: -1307.37
# Episode 180	Average Score: -1323.62
# Episode 190	Average Score: -1328.65
# Episode 200	Average Score: -1313.86
# Episode 210	Average Score: -1305.89
# Episode 220	Average Score: -1329.59
# Episode 230	Average Score: -1335.10
# Episode 240	Average Score: -1344.25
# Episode 250	Average Score: -1353.51
# Episode 260	Average Score: -1364.11
# Episode 270	Average Score: -1371.29
# Episode 280	Average Score: -1360.95
# Episode 290	Average Score: -1369.59
# Episode 300	Average Score: -1378.27
# Episode 310	Average Score: -1394.66
# Episode 320	Average Score: -1385.05
# Episode 330	Average Score: -1398.57
# Episode 340	Average Score: -1385.56
# Episode 350	Average Score: -1364.54
# Episode 360	Average Score: -1355.90
# Episode 370	Average Score: -1364.03
# Episode 380	Average Score: -1346.36
# Episode 390	Average Score: -1339.94
# Episode 400	Average Score: -1345.43
# Episode 410	Average Score: -1346.70
# Episode 420	Average Score: -1346.57
# Episode 430	Average Score: -1318.65
# Episode 440	Average Score: -1312.53
# Episode 450	Average Score: -1306.99
# Episode 460	Average Score: -1313.37
# Episode 470	Average Score: -1300.80
# Episode 480	Average Score: -1304.96
# Episode 490	Average Score: -1292.37
# Episode 500	Average Score: -1238.40

# %%
# !xdpyinfo
# load the weights from file
agent.load_state_dict(torch.load('ReinforcementLearning/checkpoint.pth'))

state = env.reset()
while True:
    state = torch.from_numpy(state).float().to(device)
    with torch.no_grad():
        action = agent(state)
    env.render()
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()
# Out:
# name of display:    :1.0
# version number:    11.0
# vendor string:    The X.Org Foundation
# vendor release number:    12009000
# X.Org version: 1.20.9
# maximum request size:  16777212 bytes
# motion buffer size:  256
# bitmap unit, bit order, padding:    32, LSBFirst, 32
# image byte order:    LSBFirst
# number of supported pixmap formats:    6
# supported pixmap formats:
#     depth 1, bits_per_pixel 1, scanline_pad 32
#     depth 4, bits_per_pixel 8, scanline_pad 32
#     depth 8, bits_per_pixel 8, scanline_pad 32
#     depth 16, bits_per_pixel 16, scanline_pad 32
#     depth 24, bits_per_pixel 32, scanline_pad 32
#     depth 32, bits_per_pixel 32, scanline_pad 32
# keycode range:    minimum 8, maximum 255
# focus:  window 0x60000a, revert to PointerRoot
# number of extensions:    23
#     BIG-REQUESTS
#     Composite
#     DAMAGE
#     DOUBLE-BUFFER
#     GLX
#     Generic Event Extension
#     MIT-SCREEN-SAVER
#     MIT-SHM
#     Present
#     RANDR
#     RECORD
#     RENDER
#     SHAPE
#     SYNC
#     VNC-EXTENSION
#     X-Resource
#     XC-MISC
#     XFIXES
#     XINERAMA
#     XInputExtension
#     XKEYBOARD
#     XTEST
#     XVideo
# default screen number:    0
# number of screens:    1
#
# screen #0:
#   dimensions:    1446x874 pixels (382x231 millimeters)
#   resolution:    96x96 dots per inch
#   depths (7):    1, 4, 8, 16, 24, 32, 24
#   root window id:    0x51a
#   depth of root window:    24 planes
#   number of colormaps:    minimum 1, maximum 1
#   default colormap:    0x20
#   default number of colormap cells:    256
#   preallocated pixels:    black 0, white 16777215
#   options:    backing-store WHEN MAPPED, save-unders NO
#   largest cursor:    1446x874
#   current input event mask:    0x72003c
#     ButtonPressMask          ButtonReleaseMask        EnterWindowMask
#     LeaveWindowMask          StructureNotifyMask      SubstructureRedirectMask
#     FocusChangeMask          PropertyChangeMask
#   number of visuals:    390
#   default visual id:  0x21
#   visual:
#     visual id:    0x396
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x397
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x398
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x399
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3aa
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ab
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ac
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ad
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ae
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3af
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ba
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3be
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bf
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ca
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ce
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cf
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3da
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3db
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3dc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3dd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3de
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3df
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ea
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3eb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ec
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ed
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ee
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ef
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fa
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fe
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ff
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x400
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x401
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x402
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x403
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x404
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x405
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x406
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x407
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x408
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x409
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x410
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x411
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x412
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x413
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x414
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x415
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x416
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x417
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x418
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x419
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x420
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x421
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x422
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x423
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x424
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x425
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x426
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x427
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x428
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x429
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x430
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x431
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x432
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x433
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x434
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x435
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x436
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x437
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x438
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x439
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x440
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x441
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x442
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x443
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x444
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x445
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x446
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x447
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x448
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x449
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44a
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44b
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44c
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44d
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44e
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44f
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x450
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x451
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x452
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x453
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
# ...
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e0
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e1
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e2
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e3
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e4
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e5
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e6
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e7
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e8
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e9
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ea
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4eb
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ec
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ed
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ee
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ef
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f0
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f1
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f2
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f3
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f4
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f5
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f6
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f7
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f8
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f9
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fa
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fb
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4d
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fc
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fd
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fe
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ff
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x500
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x501
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x502
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x503
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x504
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x505
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x506
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x507
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x508
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x509
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50a
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50b
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50c
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50d
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50e
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50f
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x510
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x511
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x512
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x513
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x514
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x515
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x516
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x517
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x518
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x21
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x22
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       8 with torch.no_grad():
#       9     action = agent(state)
# ---> 10 env.render()
#      11 next_state, reward, done, _ = env.step(action)
#      12 state = next_state
#
# File /usr/lib/python3.10/site-packages/gym/core.py:286, in Wrapper.render(self, mode, **kwargs)
#     285 def render(self, mode="human", **kwargs):
# --> 286     return self.env.render(mode, **kwargs)
#
# File /usr/lib/python3.10/site-packages/gym/core.py:286, in Wrapper.render(self, mode, **kwargs)
#     285 def render(self, mode="human", **kwargs):
# --> 286     return self.env.render(mode, **kwargs)
#
# File /usr/lib/python3.10/site-packages/gym/envs/classic_control/pendulum.py:186, in PendulumEnv.render(self, mode)
#     184 img = pygame.image.load(fname)
#     185 if self.last_u is not None:
# --> 186     scale_img = pygame.transform.smoothscale(
#     187         img, (scale * np.abs(self.last_u) / 2, scale * np.abs(self.last_u) / 2)
#     188     )
#     189     is_flip = self.last_u > 0
#     190     scale_img = pygame.transform.flip(scale_img, is_flip, True)
#
# TypeError: size must be two numbers
